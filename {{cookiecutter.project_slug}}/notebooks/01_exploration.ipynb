# %% [markdown]
# # Project: {{cookiecutter.project_name}}
# ## Notebook: 01_exploration -- Scratch Pad
#
# **Author:** {{cookiecutter.author}}
# **Description:** {{cookiecutter.description}}
#
# **Purpose:**
# [What you are trying to find out. A rough statement is fine at this stage.]
#
# **Input:**
# `data/raw/[filename]`
# Source: [where it came from, date downloaded]
#
# **Assumptions and exclusions:**
# [To be filled in as analysis develops]
#
# **Output:**
# [Any results worth keeping. Move to `data/processed/` or `outputs/figures/` if saving.
# Anything reusable moves to `02_analysis.ipynb`.]
#
# **Last updated:** [YYYY-MM-DD] | **Status:** In Progress

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Basic path setup -- no src/ required
DATA_RAW = Path('../data/raw')
PROCESSED = Path('../data/processed')
FIGURES = Path('../outputs/figures')

# %%
# If you are working in a full project with src/ available, you can use config.py instead:
# import sys
# sys.path.append('../src')
# from config import find_data, PROCESSED, FIGURES
# from plotting import save_fig

# %%
# Load data
# df = pd.read_csv(DATA_RAW / 'filename.csv')
# df.head()

# %%
# Explore
