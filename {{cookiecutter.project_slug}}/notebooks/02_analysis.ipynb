# %% [markdown]
# # Project: {{cookiecutter.project_name}}
# ## Notebook: 02_analysis -- Clean Story
#
# **Author:** {{cookiecutter.author}}
# **Description:** {{cookiecutter.description}}
#
# **Purpose:**
# [What this notebook is doing and why. Written once the approach is understood.]
#
# **Input:**
# `data/raw/[filename]`
# Source: [where it came from, date downloaded, wells or intervals included]
#
# **Assumptions and exclusions:**
# [Key decisions that affect the results. Be specific.]
#
# **Output:**
# `data/processed/[filename]`
# `outputs/figures/[filename]`
#
# **Last updated:** [YYYY-MM-DD] | **Status:** Draft

# %%
import sys
sys.path.append('../src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from config import find_data, PROCESSED, FIGURES
from plotting import save_fig

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv(find_data('filename.csv'))
df.head()

# %% [markdown]
# ## Analysis

# %%
# Analysis steps go here.
# Each section should have a markdown cell explaining the decision, not just the code.

# %% [markdown]
# ## Results

# %%
# fig, ax = plt.subplots()
# ax.plot(...)
# save_fig(fig, 'descriptive_name')

# %% [markdown]
# ## Save Outputs

# %%
# df_clean.to_csv(PROCESSED / 'filename_clean.csv', index=False)
